# %% [markdown]
# # Notebook executável
# Use funções de `churn_prediction` para evitar lógica duplicada.

# %%
from churn_prediction.config import DATA_PATH
from churn_prediction.data import eda_summary, load_churn_csv

df = load_churn_csv(DATA_PATH)
eda_summary(df)
